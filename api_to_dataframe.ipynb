# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshit-Gupta-77/Machine-Learning-Journey/blob/main/api_to_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ed24ea3e389f7d7c3fa580bbc82bd37a&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#         id                                           title  \
# 0  1560520           Batman: Knightfall Part 1: Knightfall
# 1   980431                 Avatar Aang: The Last Airbender
# 2  1007757                                         Swapped
# 3  1632181                             Accidental Partners
# 4  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
#
#                                             overview release_date  popularity  \
# 0  Arkham Asylum has been destroyed, and all its ...   2026-06-23     80.2106
# 1  Avatar Aang, the world's last Airbender, learn...   2026-07-24     85.4444
# 2  A small woodland creature and a majestic bird,...   2026-05-01     50.3237
# 3  Two women discover they were both scammed by t...   2026-03-12     17.2220
# 4  The Demon Slayer Corps are drawn into the Infi...   2025-07-18     65.2243
#
#    vote_average  vote_count
# 0         9.183         360
# 1         9.148        1173
# 2         8.866        2193
# ...

# %%
for i in range(1,429):
    response = requests.get(
    'https://api.themoviedb.org/3/movie/top_rated?api_key=ed24ea3e389f7d7c3fa580bbc82bd37a&language=en-US&page={}'.format(i)
)
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df
# Out:
#             id                                           title  \
# 0      1560520           Batman: Knightfall Part 1: Knightfall
# 1       980431                 Avatar Aang: The Last Airbender
# 2      1007757                                         Swapped
# 3      1632181                             Accidental Partners
# 4      1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# ...        ...                                             ...
# 17135   425505                                             Kin
# 17136  1317672                                 Love Me Love Me
# 17137    36670                           Never Say Never Again
# 17138    14248                                            Igor
# 17139    13168                                     Smiley Face
#
#                                                 overview release_date  \
# 0      Arkham Asylum has been destroyed, and all its ...   2026-06-23
# ...

# %%
df.shape
# Out:
# (17140, 7)

# %%
df.to_csv('movies.csv')

# %%
df
# Out:
#             id                                           title  \
# 0      1560520           Batman: Knightfall Part 1: Knightfall
# 1       980431                 Avatar Aang: The Last Airbender
# 2      1007757                                         Swapped
# 3      1632181                             Accidental Partners
# 4      1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle
# ...        ...                                             ...
# 17135   425505                                             Kin
# 17136  1317672                                 Love Me Love Me
# 17137    36670                           Never Say Never Again
# 17138    14248                                            Igor
# 17139    13168                                     Smiley Face
#
#                                                 overview release_date  \
# 0      Arkham Asylum has been destroyed, and all its ...   2026-06-23
# ...
